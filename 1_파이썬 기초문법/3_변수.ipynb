# %% [markdown]
# # **1. 변수란?**

# %% [markdown]
# * 변수는 처리할 데이터를 저장시키는 기억장소

# %%
name = '정윤서'
age = 23

print(name)
print(age)

name = '고수현'
print(name)
# Out:
# 정윤서
# 23
# 고수현

# %% [markdown]
# # **2. 변수의 이름을 작성하는 방법**

# %% [markdown]
# 1. 값이 나타내는 핵심단어
# 2. 반드시 문자로 시작해야하고, 예약어는 사용할 수 없음
# 3. 영문자, 숫자, 특수문자(_)로 사용하며 대소문자를 구별

# %%
num1 = 10
num2 = 3
print('%d / %d = %f' % (num1, num2, num1/num2))
# Out:
# 10 / 3 = 3.333333

# %%
print('num1') # 따옴표를 쓰는 순간 컴퓨터에게 이대로 출력하라고 시키는 것
# Out:
# num1

# %% [markdown]
# # **3. 변수의 데이터 타입**

# %% [markdown]
# * 데이터타입(자료형) : 자료가 저장되는 형태를 의미

# %%
name = '정윤서'
age = 20
weight = 47.5
isLover = True

# type() : 변수의 데이터 타입을 리턴해주는 함수
print(type(name)) # <class 'str'> 문자형 타입
print(type(age)) # <class 'int'> 정수형 타입
print(type(weight)) # <class 'float'> 실수형 타입
print(type(isLover)) # <class 'bool'> 논리형 타입
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# 필요없는 변수를 삭제하는 방법
del isLover

# %%
print(isLover) # NameError: name 'isLover' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6053910d0aff> in <module>()
# ----> 1 print(isLover)
#
# NameError: name 'isLover' is not defined
